# %%
import sys
import json
sys.path.append("..")  # so we can import config/ and scripts/ from project root

from dotenv import load_dotenv
load_dotenv("../.env")  # adjust path if your notebook lives elsewhere

import os
print("Key loaded:", bool(os.getenv("OPENAI_API_KEY")))
# Out:
# Key loaded: True

# %%
from openai import OpenAI
from config.schemas import CivicComplaint, IssueCategory
from scripts.generate_dataset import generate_one_sample, to_chatml_record

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
import random

samples = []
for i in range(4):
    category = random.choice(list(IssueCategory))
    sample = generate_one_sample(client, category)
    samples.append(sample)
    print(f"--- Sample {i+1} ({category.value}) ---")
    print("RAW TEXT:", sample["raw_complaint_text"])
    print("LABEL:", json.dumps(sample["structured_label"], indent=2))
    print()
# Out:
# --- Sample 1 (ILLEGAL_CONSTRUCTION) ---
# RAW TEXT: I am very frustrated with the illegal construction happening near my building on Carter Road. It's not just an eyesore; it's obstructing the view and could potentially cause safety hazards. Why is the municipal corporation allowing this? I demand immediate action to stop this construction and investigate the permits. Enough is enough!
# LABEL: {
#   "category": "ILLEGAL_CONSTRUCTION",
#   "location_raw": "Carter Road, Mumbai, Maharashtra",
#   "priority": "HIGH",
#   "sentiment": "ANGRY",
#   "description_summary": "Frustration over illegal construction causing obstruction and potential safety hazards.",
#   "language_detected": "EN",
#   "requires_immediate_attention": true
# }
#
# --- Sample 2 (NOISE_POLLUTION) ---
# ...
